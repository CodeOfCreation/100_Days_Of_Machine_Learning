# %%
import pickle
import numpy as np

# %%
pipe = pickle.load(open('pipe.pkl','rb'))

# %%
# Assume user input
test_input2 = np.array([2, 'male', 31.0, 0, 0, 10.5, 'S'],dtype=object).reshape(1,7)
pred=pipe.predict(test_input2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Assume user input
#       2 test_input2 = np.array([2, 'male', 31.0, 0, 0, 10.5, 'S'],dtype=object).reshape(1,7)
# ----> 3 pred=pipe.predict(test_input2)
#
# File c:\Users\mahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\pipeline.py:745, in Pipeline.predict(self, X, **params)
#     743 if not _routing_enabled():
#     744     for _, name, transform in self._iter(with_final=False):
# --> 745         Xt = transform.transform(Xt)
#     746     return self.steps[-1][1].predict(Xt, **params)
#     748 # metadata routing enabled
#
# File c:\Users\mahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File c:\Users\mahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\compose\_column_transformer.py:1099, in ColumnTransformer.transform(self, X, **params)
#    1096 else:
#    1097     routed_params = self._get_empty_routing()
# -> 1099 Xs = self._call_func_on_transformers(
#    1100     X,
#    1101     None,
#    1102     _transform_one,
#    1103     column_as_labels=fit_dataframe_and_transform_dataframe,
#    1104     routed_params=routed_params,
#    1105 )
#    1106 self._validate_output(Xs)
#    1108 if not Xs:
#    1109     # All transformers are None
#
# File c:\Users\mahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\compose\_column_transformer.py:893, in ColumnTransformer._call_func_on_transformers(self, X, y, func, column_as_labels, routed_params)
#     888         else:  # func is _transform_one
#     889             extra_args = {}
#     890         jobs.append(
#     891             delayed(func)(
#     892                 transformer=clone(trans) if not fitted else trans,
# --> 893                 X=_safe_indexing(X, columns, axis=1),
#     894                 y=y,
#     895                 weight=weight,
#     896                 **extra_args,
#     897                 params=routed_params[name],
#     898             )
#     899         )
#     901     return Parallel(n_jobs=self.n_jobs)(jobs)
#     903 except ValueError as e:
#
# File c:\Users\mahad\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_indexing.py:348, in _safe_indexing(X, indices, axis)
#     337     raise ValueError(
#     338         "'X' should be a 2D NumPy array, 2D sparse matrix or "
#     339         "dataframe when indexing the columns (i.e. 'axis=1'). "
#     340         f"Got {type(X)} instead with {ndim} dimension(s)."
#     341     )
#     343 if (
#     344     axis == 1
#     345     and indices_dtype == "str"
#     346     and not (is_pandas_df(X) or _use_interchange_protocol(X))
#     347 ):
# --> 348     raise ValueError(
#     349         "Specifying the columns using strings is only supported for dataframes."
#     350     )
#     352 if hasattr(X, "iloc"):
#     353     # TODO: we should probably use is_pandas_df_or_series(X) instead but:
#     354     # 1) Currently, it (probably) works for dataframes compliant to pandas' API.
#     355     # 2) Updating would require updating some tests such as
#     356     #    test_train_test_split_mock_pandas.
#     357     return _pandas_indexing(X, indices, indices_dtype, axis=axis)
#
# ValueError: Specifying the columns using strings is only supported for dataframes.
